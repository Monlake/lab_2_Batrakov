# %%
from IPython.display import Image
Image("картинки/image.png", width=320, height=240)

# %%
Image("картинки/image2.png", width=320, height=240)

# %%
Image("картинки/image3.png", width=320, height=240)
